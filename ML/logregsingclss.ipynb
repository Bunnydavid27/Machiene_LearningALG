# %%
import pandas as pd
df= pd.read_csv("D:/Computer Sciences/Data Science/HR.csv")

left = [df.left==1]
left
# Out:
# [0        True
#  1        True
#  2        True
#  3        True
#  4        True
#           ...
#  14994    True
#  14995    True
#  14996    True
#  14997    True
#  14998    True
#  Name: left, Length: 14999, dtype: bool]

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
ret=[df.left==0]
ret
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  14994    False
#  14995    False
#  14996    False
#  14997    False
#  14998    False
#  Name: left, Length: 14999, dtype: bool]

# %%
pd.crosstab(df.average_montly_hours,df.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='average_montly_hours'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Department'>

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %%
saldum = pd.get_dummies(subdf.salary,prefix='sal')
saldum
# Out:
#        sal_high  sal_low  sal_medium
# 0             0        1           0
# 1             0        0           1
# 2             0        0           1
# 3             0        1           0
# 4             0        1           0
# ...         ...      ...         ...
# 14994         0        1           0
# 14995         0        1           0
# 14996         0        1           0
# 14997         0        1           0
# 14998         0        1           0
#
# [14999 rows x 3 columns]

# %%
subdf = pd.concat([subdf,saldum],axis='columns')
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  sal_high  sal_low  sal_medium
# 0         low         0        1           0
# ...

# %%
subdf = subdf.drop(subdf[['salary']],axis='columns')
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        sal_high  sal_low  sal_medium
# 0             0        1           0
# 1             0        0           1
# ...

# %%
a = df.left
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(subdf,a)

# %%
X_train
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 9049                 0.62                   226                      0
# 5276                 0.86                   179                      0
# 4083                 0.96                   132                      0
# 13657                0.31                   132                      0
# 10543                0.15                   164                      0
# ...                   ...                   ...                    ...
# 4482                 0.51                   228                      0
# 10462                0.97                   264                      0
# 8155                 0.75                   214                      0
# 10404                0.54                   264                      0
# 531                  0.37                   131                      0
#
#        sal_high  sal_low  sal_medium
# 9049          0        0           1
# 5276          0        0           1
# ...

# %%
y_train
# Out:
# 9049     0
# 5276     0
# 4083     0
# 13657    0
# 10543    0
#         ..
# 4482     0
# 10462    0
# 8155     0
# 10404    0
# 531      1
# Name: left, Length: 11249, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
mod = LogisticRegression()

# %%
mod.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
mod.score(X_train,y_train)
# Out:
# 0.7750911192105965

# %%
mod.predict(X_test)
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int64)
